# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')    #to plot only the points
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])   #multiple points
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])   #default x as 0,1,2....

plt.plot(ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', mec ='g')  #makes each point as circle , mec is marker edge color
plt.show()

# %%
plt.plot(ypoints, marker = '*',ms = 20) #star and ms is marker size
plt.show()

# %%
plt.plot(ypoints, 'o:r') #dotted lines  #r is the color value
plt.show()

# %% [markdown]
# for more variations check out : marker references and line references

# %%
plt.plot(ypoints, 'o:b') 
plt.show()

# %%
plt.plot(ypoints, color = 'r',linestyle = 'solid',linewidth = '20.5') #color of line and width of line
plt.show()

# %% [markdown]
# plot multiple lines

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# LABELS

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.ylim(230,340) #SET X , Y AXIS SCALE
plt.xlim(70,130)

plt.plot(x, y)

plt.grid() #ADD GRID LINES #plt.grid(axis = 'x') TO ONLY DISPLAY X AXIS

plt.title("Sports Watch Data",loc = 'left') #POSITION THE TITLE
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# Multiple plots using subplot

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# The subplot() function takes three arguments
#
# rows= first argument,,,,, columns =second argument.
#
# third argument= the index of the current plot.
#
# plt.subplot(1, 2, 1)
# #the figure has 1 row, 2 columns, and this plot is the first plot.
#
# plt.subplot(1, 2, 2)
# #the figure has 1 row, 2 columns, and this plot is the second plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# SCATTER PLOTS

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
#TO COLOR EACH DOT
plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([10,20,30,40,50])
sizes = np.array([10,20,30,40,50])

plt.scatter(x, y, s=sizes, alpha=0.5)  #alpha is transparency of dots

plt.show()

# %% [markdown]
# BARS

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,width = 0.1)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y,color = "red",height = 0.5) #HORIZONTAL BARS #height is width for horizontal bars
plt.show()

# %% [markdown]
# ***HISTOGRAMS***

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
plt.hist(x,bins=20) #bins is the no of bars
plt.show()

# %%
plt.hist(x,bins=5) #bins is the no of bars
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# making a dict of list   
sale = {'type':['A', 'B', 'C','A'],'price':[1, 2, 3,4],
        'weekly_sales':[25, 50, 100,20],'holiday':[True, False, True,True]}  
sales = pd.DataFrame(sale) 
print(sales)
# Out:
#   type  price  weekly_sales  holiday
# 0    A      1            25     True
# 1    B      2            50    False
# 2    C      3           100     True
# 3    A      4            20     True

# %%
sales["weekly_sales"].hist(bins=10,alpha=0.5)
sales["price"].hist(bins=10,alpha=0.9)
plt.legend(["weekly_sales","price"])

# %% [markdown]
# PIE CHARTS

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels,shadow = True)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend(title = "Four Fruits:")
plt.show()
